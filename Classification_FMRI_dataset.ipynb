# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd '/content/drive/My Drive'
# Out:
# /content/drive/My Drive

# %%
# !pip install nilearn
# Out:
# Collecting nilearn
#   Downloading https://files.pythonhosted.org/packages/e8/e7/59fcd3501f47b7a661a69e15ef417463fbc88dd334d9af2d9d6685710038/nilearn-0.7.0-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 13.4MB/s
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.6/dist-packages (from nilearn) (0.17.0)
# Requirement already satisfied: nibabel>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from nilearn) (3.0.2)
# Requirement already satisfied: scikit-learn>=0.19 in /usr/local/lib/python3.6/dist-packages (from nilearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.6/dist-packages (from nilearn) (1.4.1)
# Requirement already satisfied: requests>=2 in /usr/local/lib/python3.6/dist-packages (from nilearn) (2.23.0)
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.6/dist-packages (from nilearn) (1.18.5)
# Requirement already satisfied: pandas>=0.18.0 in /usr/local/lib/python3.6/dist-packages (from nilearn) (1.1.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2->nilearn) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2->nilearn) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2->nilearn) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2->nilearn) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->nilearn) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.18.0->nilearn) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas>=0.18.0->nilearn) (1.15.0)
# Installing collected packages: nilearn
# Successfully installed nilearn-0.7.0

# %%
# COBRE datasets release version 0.17 preprocessed using NIAK pipeline. This
# release consists of light weight data with standard preprocessing
# steps used in functional MRI setting.

from nilearn import datasets

# all subjects (146 given in n_subjects argument)
cobre_data = datasets.fetch_cobre(n_subjects=146)
print(cobre_data.keys())
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function fetch_cobre is deprecated; 'fetch_cobre' has been deprecated and will be removed in release 0.9 . Please consider using a different datasets or downloading it with a different tool than nilearn.
#   warnings.warn(msg, category=FutureWarning)
# Dataset created in /root/nilearn_data/cobre
#
# Downloading data from https://api.figshare.com/v2/articles/4197885 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849063 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/bbfb27073f7305ba75f231550ad51673/phenotypic_data.tsv.gz..... done.
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py:2372: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   output = genfromtxt(fname, **kwargs)
# Downloading data from https://ndownloader.figshare.com/files/6848454 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848457 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/0cd5e97478f9a8e664a01eb1c6ba17e1/fmri_0040046.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848190 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848193 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/0822cabbe39213c28b7a33bea04f0ae9/fmri_0040002.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848868 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848871 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/3ea49b064cdc65d4ac19c58b94369d5a/fmri_0040117.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6849036 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849039 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/4abc23195f714fbb210d677f34285d5d/fmri_0040145.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848178 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848181 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/a7b5152347d1e56591484acae177b77d/fmri_0040000.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848352 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848355 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/f1549b465246de612b4ab314805d9a4e/fmri_0040029.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848964 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848967 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/c40fbbae26164964a850266b5eab9c1b/fmri_0040133.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848304 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848307 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/a93fad3aad3897219b9761fd2b3673c2/fmri_0040021.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848988 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848991 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/074e1a811ce944695346377d70f9971a/fmri_0040137.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848676 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848679 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/9294cb1e05427bb3045d3975619b0890/fmri_0040085.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848742 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848745 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/fe30ad948ff3c61ea5a8219012168901/fmri_0040096.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848898 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848901 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/3c999b44ec4999b7d2da82ecd0e749ec/fmri_0040122.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848310 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848313 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/456d859c3569e8f5962b80e096330062/fmri_0040022.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848610 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848613 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/2ea61e582fc3521ee2bbc6746f6184f8/fmri_0040073.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6849018 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849021 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/c6d5bd48a8b3c543c02e280f636e1c63/fmri_0040142.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848400 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848403 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/4c545e7d237bd26e3e4940de09ac74ce/fmri_0040037.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848532 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848535 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/cb2042a760d08af2da4895bec94ba766/fmri_0040059.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848604 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848607 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/8a252244ede345c00c07c732ccb7090d/fmri_0040072.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848646 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848649 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/3ca9612264cca5658926bc6823fec3f3/fmri_0040079.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848652 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848655 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/548b44ab0d8c4b98d75f6b6042327070/fmri_0040080.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848184 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848187 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre
...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848631 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/55a4b038c00fd66969b6200a66bdf8bc/fmri_0040076.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848406 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848409 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/872bb5f066fc85b420bd4ee19708cce2/fmri_0040038.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6849006 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849009 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/4f6b1d4e4494ff5a65b79a421cce5cc2/fmri_0040140.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6849030 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849033 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/72e1972585f10b4fbfb3fea4dd65c708/fmri_0040144.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848592 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848595 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/be47f798e4acd10ae7b242401b2f7a63/fmri_0040069.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848832 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848835 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/c5d2073d953d5ce3aa84b6344c27ad31/fmri_0040111.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848574 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848577 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/b17b358bde184b3622f63cbda9c959a3/fmri_0040066.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6848682 ...
#  ...done. (2 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6848685 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/cobre/46a0292e04917d03a6ce9f981944d6fa/fmri_0040086.tsv.gz..... done.
# Downloading data from https://ndownloader.figshare.com/files/6849054 ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://ndownloader.figshare.com/files/6849057 ...
# dict_keys(['func', 'confounds', 'phenotypic', 'description', 'desc_con', 'desc_phenotypic'])
#  ...done. (1 seconds, 0 min)

# %%
# Path to functional datasets for each subject
func_imgs = cobre_data.func
print("Paths to data are downloaded and stored in folder "
      "'nilearn_data' in home directory:{0}"
      .format(func_imgs[0]))
print("=============================================")

# Path to confounds: motion, slow drift, compcorr
confounds = cobre_data.confounds
print("Paths to confounds for each subject are also at "
      "stored same location "
      "as functional data:{0}".format(confounds[0]))
print("===============================================")

# Clinical variables are returned as Numpy array but not a path
phenotypes = cobre_data.phenotypic
print(phenotypes[0])
# Out:
# Paths to data are downloaded and stored in folder 'nilearn_data' in home directory:/root/nilearn_data/cobre/fmri_0040046.nii.gz
# =============================================
# Paths to confounds for each subject are also at stored same location as functional data:/root/nilearn_data/cobre/fmri_0040046.tsv
# ===============================================
# (40061, 18, b'Male', b'Right', b'Control', b'None', 133, 0.25512, 0.22657)

# %%
basc_atlases = datasets.fetch_atlas_basc_multiscale_2015()

# Now, we have atlases of all scales (n=7, 12, 20, 36, 64,
# 122, 197, 325, 444) in the networks.

atlas_img = basc_atlases['scale122']
# Out:
# Dataset created in /root/nilearn_data/basc_multiscale_2015
#
# Downloading data from https://ndownloader.figshare.com/files/1861819 ...
#  ...done. (1 seconds, 0 min)
# Extracting data from /root/nilearn_data/basc_multiscale_2015/3cbcf0eeb3f666f55070aba1db9a758f/1861819..... done.

# %%
from nilearn import plotting

plotting.plot_roi(atlas_img, cmap='Paired',
                  colorbar=True,
                  title='BASC atlas of 122 networks denoted as labels')

# %%
# For timeseries extraction from functional images, we import
# `NiftiLabelsMasker` from input_data module.

from nilearn.input_data import NiftiLabelsMasker

# We initialize the timeseries extractor by setting standard processing
# parameters required for the extraction.

timeseries_extractor = NiftiLabelsMasker(
    labels_img=atlas_img,  # brain atlas
    smoothing_fwhm=6.,  # Smoothing
    standardize=True, detrend=True, # timeseries signals
    memory='nilearn_cache',  # joblib
    memory_level=2,  # Level of caching
    verbose=2)  # useful to see processing

# We call `fit_transform` on each subject fMRI data.

# `fit` will prepare 2D data matrix from 4D functional images, whereas
# `transform` will filter, extracts and gives out cleaned signals.
# Filtering can be done based on parameters given while initialization
# and from given confounds as given in below argument.

subjects_timeseries = []

for func_img in cobre_data.func:
    signals = timeseries_extractor.fit_transform(func_img)
    subjects_timeseries.append(signals)
# Out:
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# Resampling labels
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.resampling.resample_img...
# resample_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b494860>, interpolation='nearest', target_shape=(27, 32, 26), target_affine=array([[   6.,    0.,    0.,  -78.],
#        [   0.,    6.,    0., -112.],
#        [   0.,    0.,    6.,  -68.],
#        [   0.,    0.,    0.,    1.]]))
# _____________________________________________________resample_img - 0.0s, 0.0min
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040046.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b494c88>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040046.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b494a58>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b494a20>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[958.37476, ..., 892.599  ],
#        ...,
#        [979.90546, ..., 895.17926]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040002.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72b09149b0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040002.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9eb908>, 6.0)
# /usr/local/lib/python3.6/dist-packages/nilearn/input_data/base_masker.py:99: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_labels_masker_extractor'
#   memory_level=memory_level)(imgs)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72b09149b0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e2cfcf8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[779.0736 , ..., 789.2613 ],
#        ...,
#        [770.696  , ..., 767.04114]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040117.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2a1550>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040117.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2a1550>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b971898>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b99b4a8>)
# ____________________________________nifti_labels_masker_extractor - 0.4s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[739.18665, ..., 739.2878 ],
#        ...,
#        [734.7142 , ..., 736.1556 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040145.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a04828d0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040145.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a04828d0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9f7f98>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729ba09198>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[897.2683, ..., 820.7922],
#        ...,
#        [890.9616, ..., 804.5651]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040000.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a04828d0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040000.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2d5630>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f72a08c22e8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[823.78564, ..., 850.92285],
#        ...,
#        [817.8868 , ..., 849.3867 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040029.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a04828d0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040029.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2695c0>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9f79e8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[804.3969 , ..., 772.9636 ],
#        ...,
#        [803.22076, ..., 759.96655]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040133.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a5c167f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040133.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2d52b0>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a5c167f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.2s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9780f0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[868.80597, ..., 795.40906],
#        ...,
#        [859.55286, ..., 781.59076]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040021.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040021.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2d5320>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.2s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e2890f0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[945.7827, ..., 936.2972],
#        ...,
#        [924.3032, ..., 916.6886]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040137.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99b4a8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040137.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99b4a8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9710b8>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f72a04828d0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[940.10754, ..., 872.85187],
#        ...,
#        [915.2284 , ..., 852.4105 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040085.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040085.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e289080>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b99bba8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[917.0056 , ..., 772.3118 ],
#        ...,
#        [896.91437, ..., 760.7471 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040096.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729ec71dd8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040096.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9eb908>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729ec71dd8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729ba09668>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[733.2788, ..., 710.7953],
#        ...,
#        [713.8964, ..., 680.985 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040122.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348f28>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040122.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e289080>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348f28>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b99b4a8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[826.44055, ..., 702.9455 ],
#        ...,
#        [828.7093 , ..., 697.36145]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.9s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040022.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348f28>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040022.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e281e10>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9f7668>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[804.0541, ..., 810.6327],
#        ...,
#        [826.9915, ..., 799.4019]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.1s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040073.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99be48>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040073.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b978fd0>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99be48>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9bf080>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[844.13983, ..., 761.9232 ],
#        ...,
#        [812.6353 , ..., 779.9879 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040142.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348128>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040142.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2695c0>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348128>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e2cf240>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[684.69415, ..., 710.3679 ],
#        ...,
#        [671.58563, ..., 710.86816]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040037.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a5c167f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040037.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b494978>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a5c167f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e2d5320>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[740.4741, ..., 760.705 ],
#        ...,
#        [749.8099, ..., 750.1764]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040059.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040059.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9d33c8>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9abc50>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[963.22266, ..., 858.77026],
#        ...,
#        [946.89594, ..., 853.35675]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040072.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9eb208>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040072.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9eb208>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b971ef0>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729ba09080>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[1019.59424, ...,  965.5012 ],
#        ...,
#        [ 983.6109 , ...,  941.65125]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# ...
# _______________________________________________filter_and_extract - 0.9s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040140.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72b09149b0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040140.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72b09149b0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9bf5c0>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9bfa58>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[822.6077 , ..., 801.4071 ],
#        ...,
#        [816.6313 , ..., 790.26495]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.9s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040144.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2695c0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040144.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2695c0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9d3b70>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9d3400>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[985.2569 , ..., 876.17786],
#        ...,
#        [964.2511 , ..., 860.9531 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040069.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040069.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729e2a1400>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9bf080>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[833.0807 , ..., 781.9021 ],
#        ...,
#        [821.49445, ..., 762.16986]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040111.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040111.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9abc50>, 6.0)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# _______________________________________________________smooth_img - 0.4s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e281438>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[820.38635, ..., 812.85486],
#        ...,
#        [801.84485, ..., 795.4147 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.9s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040066.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040066.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9eb208>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e269780>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[1021.4932 , ...,  914.579  ],
#        ...,
#        [ 962.56024, ...,  862.16327]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.8s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040086.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2fb7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds=None, dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040086.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# ________________________________________________________________________________
# [Memory] Calling nilearn.image.image.smooth_img...
# smooth_img(<nibabel.nifti1.Nifti1Image object at 0x7f729b9eb908>, 6.0)
# _______________________________________________________smooth_img - 0.1s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e2d5a90>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[856.6882, ..., 801.5143],
#        ...,
#        [838.7503, ..., 776.5273]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds=None, sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min

# %%
# We visualize timeseries signals by importing matplotlib

import matplotlib.pyplot as plt

# We show single subject timeseries signals extracted without confounds
plt.figure()
plt.plot(subjects_timeseries[2])
plt.title('Timeseries for single subject extracted from 122 brain regions')
plt.xlabel('Number of regions')
plt.ylabel('Normalized signal')
# Out:
# Text(0, 0.5, 'Normalized signal')

# %%
subjects_timeseries_with_confounds = []

for func_img, confound in zip(func_imgs, confounds):
    signals = timeseries_extractor.fit_transform(func_img,
                                                 confounds=confound)
    subjects_timeseries_with_confounds.append(signals)
# Out:
# /usr/local/lib/python3.6/dist-packages/nilearn/input_data/base_masker.py:99: JobLibCollisionWarning: Cannot detect name collisions for function 'nifti_labels_masker_extractor'
#   memory_level=memory_level)(imgs)
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2cfeb8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040046.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2cfeb8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040046.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040046.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]170.0s, 2.8min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2c3eb8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[958.37476, ..., 892.599  ],
#        ...,
#        [979.90546, ..., 895.17926]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040046.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040002.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040002.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040002.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]170.6s, 2.8min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2a4278>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[779.0736 , ..., 789.2613 ],
#        ...,
#        [770.696  , ..., 767.04114]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040002.tsv', sessions=None)
# ____________________________________________________________clean - 0.2s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99be48>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040117.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99be48>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040117.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040117.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]171.4s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b978080>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[739.18665, ..., 739.2878 ],
#        ...,
#        [734.7142 , ..., 736.1556 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040117.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040145.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99b4a8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040145.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040145.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b99b4a8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]172.0s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b3c2be0>)
# ____________________________________nifti_labels_masker_extractor - 0.4s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[897.2683, ..., 820.7922],
#        ...,
#        [890.9616, ..., 804.5651]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040145.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040000.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2892e8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040000.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040000.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2892e8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]172.8s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b99be48>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[823.78564, ..., 850.92285],
#        ...,
#        [817.8868 , ..., 849.3867 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040000.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040029.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729ba09080>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040029.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040029.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729ba09080>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]173.4s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2a4668>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[804.3969 , ..., 772.9636 ],
#        ...,
#        [803.22076, ..., 759.96655]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040029.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040133.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275be0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040133.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040133.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275be0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]174.2s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b47b898>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[868.80597, ..., 795.40906],
#        ...,
#        [859.55286, ..., 781.59076]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040133.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b42e7f0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040021.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b42e7f0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040021.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040021.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]175.0s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2a4ac8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[945.7827, ..., 936.2972],
#        ...,
#        [924.3032, ..., 916.6886]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040021.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040137.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b971d68>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040137.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040137.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]175.6s, 2.9min  : Loading smooth_img...
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b971d68>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b3b45c0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[940.10754, ..., 872.85187],
#        ...,
#        [915.2284 , ..., 852.4105 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040137.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040085.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9783c8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040085.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040085.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9783c8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]176.4s, 2.9min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729e354550>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[917.0056 , ..., 772.3118 ],
#        ...,
#        [896.91437, ..., 760.7471 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040085.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040096.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b494eb8>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040096.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040096.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b494eb8>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]177.0s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b37f5c0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[733.2788, ..., 710.7953],
#        ...,
#        [713.8964, ..., 680.985 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040096.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040122.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b396d30>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040122.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040122.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b396d30>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]177.8s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b350710>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[826.44055, ..., 702.9455 ],
#        ...,
#        [828.7093 , ..., 697.36145]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040122.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348240>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040022.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e348240>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040022.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040022.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]178.5s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b3b45c0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[804.0541, ..., 810.6327],
#        ...,
#        [826.9915, ..., 799.4019]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040022.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040073.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b3eee80>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040073.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040073.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b3eee80>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]179.2s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9712e8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[844.13983, ..., 761.9232 ],
#        ...,
#        [812.6353 , ..., 779.9879 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040073.tsv', sessions=None)
# ____________________________________________________________clean - 0.2s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b47b828>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040142.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b47b828>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040142.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040142.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]179.9s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2a4c88>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[684.69415, ..., 710.3679 ],
#        ...,
#        [671.58563, ..., 710.86816]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040142.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040037.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b47bcc0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040037.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040037.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b47bcc0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]180.6s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b30f780>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[740.4741, ..., 760.705 ],
#        ...,
#        [749.8099, ..., 750.1764]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040037.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040059.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040059.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040059.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e2b3550>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]181.3s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b3fce10>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[963.22266, ..., 858.77026],
#        ...,
#        [946.89594, ..., 853.35675]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040059.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b409080>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040072.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b409080>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040072.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040072.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]182.1s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b47bcc0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[1019.59424, ...,  965.5012 ],
#        ...,
#        [ 983.6109 , ...,  941.65125]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040072.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040079.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a0482a20>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040079.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040079.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f72a0482a20>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]182.8s, 3.0min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9789b0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[767.0893 , ..., 739.10333],
#        ...,
# ...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f72a08c25c0>)
# ____________________________________nifti_labels_masker_extractor - 0.4s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[889.447  , ..., 823.3852 ],
#        ...,
#        [861.52856, ..., 809.56085]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040038.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040140.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9b61d0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040140.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040140.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9b61d0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]270.7s, 4.5min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b37fa20>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[822.6077 , ..., 801.4071 ],
#        ...,
#        [816.6313 , ..., 790.26495]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040140.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040144.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275da0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040144.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040144.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275da0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]271.3s, 4.5min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b31efd0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[985.2569 , ..., 876.17786],
#        ...,
#        [964.2511 , ..., 860.9531 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040144.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040069.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b971d68>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040069.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040069.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b971d68>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]272.2s, 4.5min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b360b00>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[833.0807 , ..., 781.9021 ],
#        ...,
#        [821.49445, ..., 762.16986]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040069.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040111.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9ab1d0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040111.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040111.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9ab1d0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]273.0s, 4.5min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b9783c8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[820.38635, ..., 812.85486],
#        ...,
#        [801.84485, ..., 795.4147 ]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040111.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.5s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040066.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9f7828>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040066.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040066.nii.gz
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729b9f7828>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# [Memory]273.6s, 4.6min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b2aaeb8>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[1021.4932 , ...,  914.579  ],
#        ...,
#        [ 962.56024, ...,  862.16327]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040066.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.7s, 0.0min
# [NiftiLabelsMasker.fit_transform] loading data from /root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.base_masker.filter_and_extract...
# filter_and_extract('/root/nilearn_data/cobre/fmri_0040086.nii.gz', <nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275be0>,
# { 'background_label': 0,
#   'detrend': True,
#   'dtype': None,
#   'high_pass': None,
#   'labels_img': '/root/nilearn_data/basc_multiscale_2015/template_cambridge_basc_multiscale_nii_sym/template_cambridge_basc_multiscale_sym_scale122.nii.gz',
#   'low_pass': None,
#   'mask_img': None,
#   'smoothing_fwhm': 6.0,
#   'standardize': True,
#   'strategy': 'mean',
#   't_r': None,
#   'target_affine': None,
#   'target_shape': None}, confounds='/root/nilearn_data/cobre/fmri_0040086.tsv', dtype=None, memory=Memory(location=nilearn_cache/joblib), memory_level=2, verbose=2)
# [NiftiLabelsMasker.transform_single_imgs] Loading data from /root/nilearn_data/cobre/fmri_0040086.nii.gz
# [NiftiLabelsMasker.transform_single_imgs] Smoothing images
# WARNING:root:[MemorizedFunc(func=<nilearn.input_data.nifti_labels_masker._ExtractionFunctor object at 0x7f729e275be0>, location=nilearn_cache/joblib)]: Clearing function cache identified by nilearn/input_data/nifti_labels_masker/nifti_labels_masker_extractor
# [Memory]274.4s, 4.6min  : Loading smooth_img...
# [NiftiLabelsMasker.transform_single_imgs] Extracting region signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.input_data.nifti_labels_masker.nifti_labels_masker_extractor...
# nifti_labels_masker_extractor(<nibabel.nifti1.Nifti1Image object at 0x7f729b3b45c0>)
# ____________________________________nifti_labels_masker_extractor - 0.3s, 0.0min
# [NiftiLabelsMasker.transform_single_imgs] Cleaning extracted signals
# ________________________________________________________________________________
# [Memory] Calling nilearn.signal.clean...
# clean(array([[856.6882, ..., 801.5143],
#        ...,
#        [838.7503, ..., 776.5273]], dtype=float32), detrend=True, standardize=True, t_r=None, low_pass=None, high_pass=None, confounds='/root/nilearn_data/cobre/fmri_0040086.tsv', sessions=None)
# ____________________________________________________________clean - 0.0s, 0.0min
# _______________________________________________filter_and_extract - 0.6s, 0.0min

# %%
# We use same matplotlib.pyplot to plot the signals
plt.figure()
plt.plot(subjects_timeseries_with_confounds[2])
plt.title('Timeseries signal (after removing confounds)')
plt.xlabel('Number of regions')
plt.ylabel('Normalized signal')
# Out:
# Text(0, 0.5, 'Normalized signal')

# %%
# Build connectivity matrices using simple 'correlation'
# on extracted timeseries signals

# We import `ConnectivityMeasure` from connectome
# module and covariance
# estimator LedoitWolf from scikit learn to
# build connectivity matrices.
from sklearn.covariance import LedoitWolf
from nilearn.connectome import ConnectivityMeasure

# Initialize `ConnectivityMeasure` and measure
# set in argument 'kind' and 'cov_estimator'
connectivity = ConnectivityMeasure(
    kind='correlation',
    cov_estimator=LedoitWolf(assume_centered=True))
connectivity_matrices = connectivity.fit_transform(subjects_timeseries_with_confounds)

# %%
# First, we get the mean of the correlation matrix
mean_correlation_matrix = connectivity_matrices.mean(axis=0)

# Second, visualizing goes here using matplotlib

title = ('Mean over all connectivity matrices with measure "correlation"')
plt.figure()
plt.title(title)
plt.imshow(mean_correlation_matrix, cmap='Paired')
plt.colorbar()
plt.show()

# %%
from nilearn.connectome import sym_to_vec

connectivity_coefs = sym_to_vec(connectivity_matrices)
# Now, we have connectivity coefficients of all subjects
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function sym_to_vec is deprecated; Function 'sym_to_vec' has been renamed to 'sym_matrix_to_vec' and will be removed in 0.8
#   warnings.warn(msg, category=FutureWarning)

# %%
import numpy as np
from sklearn.model_selection import StratifiedShuffleSplit

n_iter = 100  # Number of splits
class_type = 'subject_type'  # from phenotypes in cobre data return
classes = np.asarray(phenotypes[class_type])
_, classes_binary = np.unique(classes, return_inverse=True)
cv = StratifiedShuffleSplit(n_splits=n_iter,
                            test_size=0.25,
                            random_state=0)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.svm import LinearSVC

svc = LinearSVC(penalty='l2', random_state=0)
iter_for_prediction = cv.split(func_imgs, classes_binary)
scores = []
# Try cv.get_n_splits()
for index, (train_index, test_index) in enumerate(iter_for_prediction):
    prediction_scores = cross_val_score(
        estimator=svc,  # classifier
        X=connectivity_coefs,  # Data to fit
        y=classes_binary,  # Target variables
        scoring='roc_auc',  # scoring
        cv=[(train_index, test_index)],
        )
    scores.append(prediction_scores)  # for each split we gather scores

scores = np.asarray(scores)
print(" -- Support Vector Classification -- ")
print("Classification scores '%s': %1.2f +/- %1.2f" % ('correlation',
                                                       scores.mean(),
                                                       scores.std()))
# Out:
#  -- Support Vector Classification --
# Classification scores 'correlation': 0.58 +/- 0.07

# %%
# We try to improve classification accuracy by using different measure
# We repeat the same steps as above from Step 3 but using now kind='tangent' to
# see if we can improve our classification accuracy
connectivity = ConnectivityMeasure(
    kind='tangent',
    cov_estimator=LedoitWolf(assume_centered=True))
# Compute connectome matrices
connectivity_matrices = connectivity.fit_transform(subjects_timeseries_with_confounds)

# %%
# First, we get the mean of the tangent matrix from attribute 'mean_'
mean_tangent_matrix = connectivity.mean_

# Second, visualizing goes here using matplotlib

title = ('Mean over all connectivity matrices with measure "tangent"')
plt.figure()
plt.title(title)
plt.imshow(mean_tangent_matrix, cmap='Paired')
plt.colorbar()
plt.show()

# %%
# Convert connectivity matrices to connectivity vectors
connectivity_coefs2 = sym_to_vec(connectivity_matrices)

# Use them again for classification by using the same cross validator
iter_for_prediction2 = cv.split(func_imgs, classes_binary)
scores2 = []

for index, (train_index, test_index) in enumerate(iter_for_prediction2):
    prediction_scores2 = cross_val_score(
        estimator=svc,  # classifier
        X=connectivity_coefs2,  # Data to fit
        y=classes_binary,  # Target variables
        scoring='roc_auc',  # scoring
        cv=[(train_index, test_index)],
        )
    scores2.append(prediction_scores2)  # for each split we gather scores

scores2 = np.asarray(scores2)
print(" -- Support Vector Classification with Tangent Space measure -- ")
print("Classification scores '%s': %1.2f +/- %1.2f" % ('tangent',
                                                       scores2.mean(),
                                                       scores2.std()))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function sym_to_vec is deprecated; Function 'sym_to_vec' has been renamed to 'sym_matrix_to_vec' and will be removed in 0.8
#   warnings.warn(msg, category=FutureWarning)
#  -- Support Vector Classification with Tangent Space measure --
# Classification scores 'tangent': 0.63 +/- 0.08
